# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1,4,2,4,6,1,7,12]
plt.plot(x)
plt.show()

# %%
iris_data = np.loadtxt('../iris-dataset/iris.data.txt', delimiter=',', usecols=range(0,4))

# %%
plt.plot(iris_data[:50,0], c='r', ls='-', marker='o', label='Comp. Sépala Iris Setosa')
plt.plot(iris_data[50:100,0], c='b', ls='--', marker='o', label='Comp. Sépala Iris Versicolo')
plt.legend(loc='best') #loc='upper left'
plt.show()
