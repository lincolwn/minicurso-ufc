# %%
# ex: df = pd.read_csv(filepath, delimiter)
# ex: df = pd.read_excel(filepath)

import pandas as pd
from pydataset import data

# %%
df = data('titanic')

# %%
df.columns
# Out:
# Index(['class', 'age', 'sex', 'survived'], dtype='object')

# %%
df[df['age'] == 'child']
# Out:
#           class    age    sex survived
# 320   1st class  child    man      yes
# 321   1st class  child    man      yes
# 322   1st class  child    man      yes
# 323   1st class  child    man      yes
# 324   1st class  child    man      yes
# 325   1st class  child  women      yes
# 587   2nd class  child    man      yes
# 588   2nd class  child    man      yes
# 589   2nd class  child    man      yes
# 590   2nd class  child    man      yes
# 591   2nd class  child    man      yes
# 592   2nd class  child    man      yes
# 593   2nd class  child    man      yes
# 594   2nd class  child    man      yes
# 595   2nd class  child    man      yes
# 596   2nd class  child    man      yes
# 597   2nd class  child    man      yes
# 598   2nd class  child  women      yes
# 599   2nd class  child  women      yes
# 600   2nd class  child  women      yes
# 601   2nd class  child  women      yes
# 602   2nd class  child  women      yes
# 603   2nd class  child  women      yes
# ...
